# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import re
from collections import OrderedDict

# ==== CONFIG ====
base_model_id = "tiiuae/falcon-rw-1b"  # or your own base path if different
adapter_model_ids = {
    "toxicity": "Kavanavnlp/falcon-1b-toxicity-qa-10k",
    "medical": "Kavanavnlp/falcon-1b-medical-qa-10k",
    "finance": "Kavanavnlp/falcon-1b-finance-qa-10k"
}
output_dir = "./merged_falcon_model"

# ==== Exclude only embeddings and final layer norm — keep lm_head ====
exclude_param_names_regex = [
    r"^model.embed_tokens.*",
    r"^model.final_layer_norm.*"
]

def should_exclude(name, patterns):
    return any(re.match(p, name) for p in patterns)

# ==== Load base model ====
print(f"🔹 Loading base model: {base_model_id}")
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=torch.float16,
    device_map="cpu"
)

# ==== Load and merge LoRA adapters ====
merged_models = []
for task, adapter_id in adapter_model_ids.items():
    print(f"🔹 Loading adapter for {task} from: {adapter_id}")
    adapter_model = PeftModel.from_pretrained(base_model, adapter_id)
    adapter_model = adapter_model.merge_and_unload()  # Merge LoRA weights into full model
    merged_models.append(adapter_model)

# ==== Merge parameters ====
print("🔹 Merging model parameters ...")
merged_state_dict = OrderedDict()

for name, base_param in base_model.named_parameters():
    if should_exclude(name, exclude_param_names_regex):
        merged_state_dict[name] = base_param.data.clone()
        continue

    # Start from base param
    avg_param = base_param.data.clone().float()

    # Add from all adapters
    for model in merged_models:
        avg_param += model.state_dict()[name].float()

    # Average across base + N adapters
    avg_param /= (len(merged_models) + 1)
    merged_state_dict[name] = avg_param.to(base_param.dtype)

# === Fix: Ensure lm_head.weight is present ===
if "lm_head.weight" not in merged_state_dict:
    print("🔸 Adding lm_head.weight from base model")
    merged_state_dict["lm_head.weight"] = base_model.state_dict()["lm_head.weight"]

# ==== Load final merged weights ====
print("🔹 Loading merged weights into base model")
base_model.load_state_dict(merged_state_dict)

# ==== Save final merged model ====
print(f"💾 Saving merged model to {output_dir}")
base_model.save_pretrained(output_dir)
AutoTokenizer.from_pretrained(base_model_id).save_pretrained(output_dir)

print("✅ Done! Merged model is ready.")
# Out:
# 🔹 Loading base model: tiiuae/falcon-rw-1b
# 🔹 Loading adapter for toxicity from: Kavanavnlp/falcon-1b-toxicity-qa-10k
# 🔹 Loading adapter for medical from: Kavanavnlp/falcon-1b-medical-qa-10k
# 🔹 Loading adapter for finance from: Kavanavnlp/falcon-1b-finance-qa-10k
# 🔹 Merging model parameters ...
# 🔸 Adding lm_head.weight from base model
# 🔹 Loading merged weights into base model
# 💾 Saving merged model to ./merged_falcon_model
# tokenizer_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# ✅ Done! Merged model is ready.

# %%
import json
from transformers import pipeline

base_model_id = "tiiuae/falcon-rw-1b"
merged_model_dir = "./merged_falcon_model"

# Load generation pipelines
pipe_base = pipeline("text-generation", model=base_model_id, tokenizer=base_model_id, device=0)
pipe_merged = pipeline("text-generation", model=merged_model_dir, tokenizer=merged_model_dir, device=0)

# Load prompts
with open("eval_prompts.json") as f:
    prompts = json.load(f)

results = []
for p in prompts:
    prompt = p["prompt"]

    base_out = pipe_base(prompt, max_new_tokens=150, do_sample=False)[0]["generated_text"]
    merged_out = pipe_merged(prompt, max_new_tokens=150, do_sample=False)[0]["generated_text"]

    results.append({
        "id": p["id"],
        "domain": p["domain"],
        "prompt": prompt,
        "base_response": base_out.strip(),
        "merged_response": merged_out.strip()
    })

# Save responses
with open("model_outputs.json", "w") as f:
    json.dump(results, f, indent=2)

print("✅ Model outputs saved.")
# Out:
# Device set to use cuda:0
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ✅ Model outputs saved.

# %%
# !pip install git+https://github.com/EleutherAI/lm-evaluation-harness.git@main
# !pip install accelerate einops bitsandbytes transformers datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

BASE_MODEL = "tiiuae/falcon-rw-1b"
MERGED_MODEL = "/content/drive/MyDrive/merged_falcon_model"
TASKS = "nq_open,commonsense_qa,toxigen"
OUTPUT_DIR = "./eval_outputs"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ## **Toxicity**

# %%
# !lm-eval \
  --model hf \
  --model_args pretrained=tiiuae/falcon-rw-1b \
  --tasks nq_open,commonsense_qa,toxigen \
  --device cuda \
  --batch_size 32 \
  --trust_remote_code \
  --output_path eval_outputs/base_results.json
# Out:
# 2025-05-10 02:25:27.098215: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 02:25:27.114743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746843927.135738    7129 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746843927.142171    7129 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 02:25:27.163086: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-10:02:25:33 INFO     [__main__:428] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-10:02:25:33 INFO     [__main__:440] Selected Tasks: ['commonsense_qa', 'nq_open', 'toxigen']
# 2025-05-10:02:25:33 INFO     [evaluator:185] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-10:02:25:33 INFO     [evaluator:223] Initializing hf model, with arguments: {'pretrained': 'tiiuae/falcon-rw-1b', 'trust_remote_code': True}
# 2025-05-10:02:25:33 INFO     [models.huggingface:137] Using device 'cuda'
# configuration_falcon.py: 100% 6.70k/6.70k [00:00<00:00, 38.6MB/s]
# 2025-05-10:02:25:34 INFO     [models.huggingface:382] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda'}
# modeling_falcon.py: 100% 56.9k/56.9k [00:00<00:00, 4.68MB/s]
# README.md: 100% 7.39k/7.39k [00:00<00:00, 39.4MB/s]
# train-00000-of-00001.parquet: 100% 1.25M/1.25M [00:00<00:00, 18.8MB/s]
# validation-00000-of-00001.parquet: 100% 160k/160k [00:00<00:00, 351MB/s]
# test-00000-of-00001.parquet: 100% 151k/151k [00:00<00:00, 364MB/s]
# Generating train split: 100% 9741/9741 [00:00<00:00, 199446.99 examples/s]
# Generating validation split: 100% 1221/1221 [00:00<00:00, 281557.27 examples/s]
# Generating test split: 100% 1140/1140 [00:00<00:00, 287540.23 examples/s]
# README.md: 100% 8.77k/8.77k [00:00<00:00, 43.2MB/s]
# train-00000-of-00001.parquet: 100% 4.46M/4.46M [00:00<00:00, 149MB/s]
# validation-00000-of-00001.parquet: 100% 214k/214k [00:00<00:00, 349MB/s]
# Generating train split: 100% 87925/87925 [00:00<00:00, 2305261.32 examples/s]
# Generating validation split: 100% 3610/3610 [00:00<00:00, 1096411.11 examples/s]
# README.md: 100% 10.7k/10.7k [00:00<00:00, 59.6MB/s]
# test-00000-of-00001.parquet: 100% 79.7k/79.7k [00:00<00:00, 252MB/s]
# train-00000-of-00001.parquet: 100% 689k/689k [00:00<00:00, 257MB/s]
# Generating test split: 100% 940/940 [00:00<00:00, 197973.68 examples/s]
# Generating train split: 100% 8960/8960 [00:00<00:00, 762755.51 examples/s]
# 2025-05-10:02:25:47 INFO     [evaluator:286] nq_open: Using gen_kwargs: {'until': ['\n', '.', ','], 'do_sample': False, 'temperature': 0.0}
# 2025-05-10:02:25:47 INFO     [api.task:434] Building contexts for toxigen on rank 0...
# 100% 940/940 [00:00<00:00, 2320.85it/s]
# 2025-05-10:02:25:47 INFO     [api.task:434] Building contexts for nq_open on rank 0...
# 100% 3610/3610 [00:02<00:00, 1438.35it/s]
# 2025-05-10:02:25:50 INFO     [api.task:434] Building contexts for commonsense_qa on rank 0...
# 100% 1221/1221 [00:02<00:00, 492.14it/s]
# 2025-05-10:02:25:52 INFO     [evaluator:559] Running loglikelihood requests
# Running loglikelihood requests: 100% 7985/7985 [00:03<00:00, 2040.15it/s]
# 2025-05-10:02:25:58 INFO     [evaluator:559] Running generate_until requests
# Running generate_until requests: 100% 3610/3610 [06:23<00:00,  9.42it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-10:02:32:26 INFO     [loggers.evaluation_tracker:209] Saving results aggregated
# hf (pretrained=tiiuae/falcon-rw-1b,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# |    Tasks     |Version|     Filter      |n-shot|  Metric   |   |Value |   |Stderr|
# |--------------|-------|-----------------|-----:|-----------|---|-----:|---|-----:|
# |commonsense_qa|Yaml   |none             |     0|acc        |↑  |0.1982|±  |0.0114|
# |nq_open       |      4|remove_whitespace|     0|exact_match|↑  |0.0493|±  |0.0036|
# |toxigen       |      1|none             |     0|acc        |↑  |0.4255|±  |0.0161|
# |              |       |none             |     0|acc_norm   |↑  |0.4319|±  |0.0162|

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig

base_model_id = "tiiuae/falcon-rw-1b"
output_dir = "/content/drive/MyDrive/merged_falcon_model"

# Load base model again
base_model = AutoModelForCausalLM.from_pretrained(base_model_id, torch_dtype=torch.float16)

# Now load your merged_state_dict (assumes you've kept it)
# base_model.load_state_dict(merged_state_dict)  # <-- do this only if you still have merged weights

# Save full model
base_model.save_pretrained(output_dir)
AutoConfig.from_pretrained(base_model_id).save_pretrained(output_dir)
AutoTokenizer.from_pretrained(base_model_id).save_pretrained(output_dir)

print("✅ Merged model with weights, config, and tokenizer saved.")
# Out:
# ✅ Merged model with weights, config, and tokenizer saved.

# %%
# !lm-eval \
  --model hf \
  --model_args pretrained=/content/drive/MyDrive/merged_falcon_model \
  --tasks nq_open,commonsense_qa,toxigen \
  --device cuda \
  --batch_size 32 \
  --trust_remote_code \
  --output_path eval_outputs/merged_results.json
# Out:
# 2025-05-10 02:39:09.741754: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746844749.762887   10943 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746844749.769485   10943 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10:02:39:16 INFO     [__main__:428] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-10:02:39:16 INFO     [__main__:440] Selected Tasks: ['commonsense_qa', 'nq_open', 'toxigen']
# 2025-05-10:02:39:16 INFO     [evaluator:185] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-10:02:39:16 INFO     [evaluator:223] Initializing hf model, with arguments: {'pretrained': '/content/drive/MyDrive/merged_falcon_model', 'trust_remote_code': True}
# 2025-05-10:02:39:16 INFO     [models.huggingface:137] Using device 'cuda'
# 2025-05-10:02:39:16 INFO     [models.huggingface:382] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda'}
# 2025-05-10:02:39:27 INFO     [evaluator:286] nq_open: Using gen_kwargs: {'until': ['\n', '.', ','], 'do_sample': False, 'temperature': 0.0}
# 2025-05-10:02:39:27 INFO     [api.task:434] Building contexts for toxigen on rank 0...
# 100% 940/940 [00:00<00:00, 2360.84it/s]
# 2025-05-10:02:39:27 INFO     [api.task:434] Building contexts for nq_open on rank 0...
# 100% 3610/3610 [00:02<00:00, 1445.23it/s]
# 2025-05-10:02:39:30 INFO     [api.task:434] Building contexts for commonsense_qa on rank 0...
# 100% 1221/1221 [00:02<00:00, 580.10it/s]
# 2025-05-10:02:39:32 INFO     [evaluator:559] Running loglikelihood requests
# Running loglikelihood requests: 100% 7985/7985 [00:03<00:00, 2074.70it/s]
# 2025-05-10:02:39:38 INFO     [evaluator:559] Running generate_until requests
# Running generate_until requests: 100% 3610/3610 [06:35<00:00,  9.13it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-10:02:46:18 INFO     [loggers.evaluation_tracker:209] Saving results aggregated
# hf (pretrained=/content/drive/MyDrive/merged_falcon_model,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# |    Tasks     |Version|     Filter      |n-shot|  Metric   |   |Value |   |Stderr|
# |--------------|-------|-----------------|-----:|-----------|---|-----:|---|-----:|
# |commonsense_qa|Yaml   |none             |     0|acc        |↑  |0.1941|±  |0.0113|
# |nq_open       |      4|remove_whitespace|     0|exact_match|↑  |0.0485|±  |0.0036|
# |toxigen       |      1|none             |     0|acc        |↑  |0.4266|±  |0.0161|
# |              |       |none             |     0|acc_norm   |↑  |0.4330|±  |0.0162|

# %% [markdown]
# ## **Medical**

# %%
# !pip install git+https://github.com/google-research/bleurt.git

# %%
# !lm-eval \
  --model hf \
  --model_args pretrained=./merged_falcon_model \
  --tasks medmcqa,pubmedqa,medtext \
  --device cuda \
  --batch_size 32 \
  --trust_remote_code \
  --output_path results_merged.json
# Out:
# 2025-05-10 03:22:37.320779: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 03:22:37.338673: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746847357.360202   24018 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746847357.366818   24018 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 03:22:37.388887: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-10:03:22:44 INFO     [__main__:428] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-10:03:22:44 INFO     [__main__:440] Selected Tasks: ['medmcqa', 'medtext', 'pubmedqa']
# 2025-05-10:03:22:44 INFO     [evaluator:185] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-10:03:22:44 INFO     [evaluator:223] Initializing hf model, with arguments: {'pretrained': './merged_falcon_model', 'trust_remote_code': True}
# 2025-05-10:03:22:44 INFO     [models.huggingface:137] Using device 'cuda'
# 2025-05-10:03:22:44 INFO     [models.huggingface:382] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda'}
# Downloading data: 100% 405M/405M [00:02<00:00, 172MB/s]
# INFO:tensorflow:Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# 2025-05-10:03:23:14 INFO     [tensorflow:160] Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# INFO:tensorflow:Config file found, reading.
# 2025-05-10:03:23:14 INFO     [tensorflow:91] Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# 2025-05-10:03:23:14 INFO     [tensorflow:95] Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# 2025-05-10:03:23:14 INFO     [tensorflow:97] Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# 2025-05-10:03:23:14 INFO     [tensorflow:101] ... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# 2025-05-10:03:23:14 INFO     [tensorflow:101] ... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# 2025-05-10:03:23:14 INFO     [tensorflow:101] ... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# 2025-05-10:03:23:14 INFO     [tensorflow:101] ... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# 2025-05-10:03:23:14 INFO     [tensorflow:101] ... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# 2025-05-10:03:23:14 INFO     [tensorflow:167] Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# 2025-05-10:03:23:14 INFO     [tensorflow:40] Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# 2025-05-10:03:23:14 INFO     [tensorflow:45] WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# 2025-05-10:03:23:14 INFO     [tensorflow:56] Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# 2025-05-10:03:23:14 INFO     [tensorflow:61] Loading model.
# 2025-05-10 03:23:15.181854: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1746847395.183723   24018 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 35844 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# 2025-05-10:03:23:17 INFO     [absl:1083] Fingerprint not found. Saved model loading will continue.
# 2025-05-10:03:23:17 INFO     [absl:1102] path_and_singleprint metric could not be logged. Saved model loading will continue.
# INFO:tensorflow:BLEURT initialized.
# 2025-05-10:03:23:17 INFO     [tensorflow:173] BLEURT initialized.
# INFO:tensorflow:Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# 2025-05-10:03:23:19 INFO     [tensorflow:160] Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# INFO:tensorflow:Config file found, reading.
# 2025-05-10:03:23:19 INFO     [tensorflow:91] Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# 2025-05-10:03:23:19 INFO     [tensorflow:95] Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# 2025-05-10:03:23:19 INFO     [tensorflow:97] Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# 2025-05-10:03:23:19 INFO     [tensorflow:101] ... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# 2025-05-10:03:23:19 INFO     [tensorflow:101] ... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# 2025-05-10:03:23:19 INFO     [tensorflow:101] ... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# 2025-05-10:03:23:19 INFO     [tensorflow:101] ... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# 2025-05-10:03:23:19 INFO     [tensorflow:101] ... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# 2025-05-10:03:23:19 INFO     [tensorflow:167] Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# 2025-05-10:03:23:19 INFO     [tensorflow:40] Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# 2025-05-10:03:23:19 INFO     [tensorflow:45] WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# 2025-05-10:03:23:19 INFO     [tensorflow:56] Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# 2025-05-10:03:23:19 INFO     [tensorflow:61] Loading model.
# 2025-05-10:03:23:21 INFO     [absl:1083] Fingerprint not found. Saved model loading will continue.
# 2025-05-10:03:23:21 INFO     [absl:1102] path_and_singleprint metric could not be logged. Saved model loading will continue.
# INFO:tensorflow:BLEURT initialized.
# 2025-05-10:03:23:22 INFO     [tensorflow:173] BLEURT initialized.
# INFO:tensorflow:Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# 2025-05-10:03:23:24 INFO     [tensorflow:160] Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# INFO:tensorflow:Config file found, reading.
# 2025-05-10:03:23:24 INFO     [tensorflow:91] Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# 2025-05-10:03:23:24 INFO     [tensorflow:95] Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# 2025-05-10:03:23:24 INFO     [tensorflow:97] Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# 2025-05-10:03:23:24 INFO     [tensorflow:101] ... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# 2025-05-10:03:23:24 INFO     [tensorflow:101] ... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# 2025-05-10:03:23:24 INFO     [tensorflow:101] ... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# 2025-05-10:03:23:24 INFO     [tensorflow:101] ... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# 2025-05-10:03:23:24 INFO     [tensorflow:101] ... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# 2025-05-10:03:23:24 INFO     [tensorflow:167] Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# 2025-05-10:03:23:24 INFO     [tensorflow:40] Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# 2025-05-10:03:23:24 INFO     [tensorflow:45] WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# 2025-05-10:03:23:24 INFO     [tensorflow:56] Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# 2025-05-10:03:23:24 INFO     [tensorflow:61] Loading model.
# 2025-05-10:03:23:26 INFO     [absl:1083] Fingerprint not found. Saved model loading will continue.
# 2025-05-10:03:23:26 INFO     [absl:1102] path_and_singleprint metric could not be logged. Saved model loading will continue.
# INFO:tensorflow:BLEURT initialized.
# 2025-05-10:03:23:26 INFO     [tensorflow:173] BLEURT initialized.
# README.md: 100% 4.84k/4.84k [00:00<00:00, 24.4MB/s]
# medtext_2.csv: 100% 940k/940k [00:00<00:00, 17.6MB/s]
# Generating train split: 100% 1412/1412 [00:00<00:00, 68386.71 examples/s]
# README.md: 100% 2.36k/2.36k [00:00<00:00, 22.5MB/s]
# pubmed_qa.py: 100% 10.3k/10.3k [00:00<00:00, 50.7MB/s]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# bigbiohub.py: 100% 19.3k/19.3k [00:00<00:00, 92.1MB/s]
# pqal.zip: 100% 4.24M/4.24M [00:00<00:00, 46.9MB/s]
# Generating train split: 450 examples [00:00, 10803.75 examples/s]
# Generating validation split: 50 examples [00:00, 7060.64 examples/s]
# Generating test split: 500 examples [00:00, 11818.07 examples/s]
# 2025-05-10:03:23:28 INFO     [evaluator:286] medtext: Using gen_kwargs: {'until': ['\n\n']}
# 2025-05-10:03:23:28 INFO     [api.task:434] Building contexts for pubmedqa on rank 0...
# 100% 500/500 [00:00<00:00, 83963.33it/s]
# 2025-05-10:03:23:28 INFO     [api.task:434] Building contexts for medtext on rank 0...
# 100% 1412/1412 [00:00<00:00, 3141.28it/s]
# 2025-05-10:03:23:29 INFO     [api.task:434] Building contexts for medmcqa on rank 0...
# 100% 4183/4183 [00:00<00:00, 81770.56it/s]
# 2025-05-10:03:23:29 INFO     [evaluator:559] Running loglikelihood requests
# Running loglikelihood requests: 100% 18232/18232 [00:13<00:00, 1340.98it/s]
# 2025-05-10:03:23:52 INFO     [evaluator:559] Running generate_until requests
# Running generate_until requests: 100% 1412/1412 [04:57<00:00,  4.75it/s]
# 2025-05-10:03:28:49 INFO     [absl:83] Using default tokenizer.
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 180kB/s]
# config.json: 100% 482/482 [00:00<00:00, 4.78MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 12.5MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 73.3MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 10.6MB/s]
# model.safetensors: 100% 1.42G/1.42G [00:06<00:00, 212MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-05-10:03:29:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:29:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:30:52 INFO     [absl:83] Using default tokenizer.
# ...
# 2025-05-10:03:32:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:32:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:33:23 INFO     [absl:83] Using default tokenizer.
# bootstrapping for stddev: nanmean
# 100% 1/1 [00:00<00:00, 25.83it/s]
# bootstrapping for stddev: nanmean
# 100% 100/100 [00:05<00:00, 16.80it/s]
# bootstrapping for stddev: nanmean
# 100% 100/100 [00:05<00:00, 17.90it/s]
# bootstrapping for stddev: nanmean
# 100% 100/100 [00:05<00:00, 17.14it/s]
# bootstrapping for stddev: nanmean
# 100% 100/100 [00:05<00:00, 17.79it/s]
# bootstrapping for stddev: nanmean
# 100% 100/100 [00:05<00:00, 17.73it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-10:03:33:57 INFO     [loggers.evaluation_tracker:209] Saving results aggregated
# hf (pretrained=./merged_falcon_model,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|  Metric  |   | Value |   |Stderr|
# |--------|-------|------|-----:|----------|---|------:|---|-----:|
# |medmcqa |Yaml   |none  |     0|acc       |↑  | 0.2553|±  |0.0067|
# |        |       |none  |     0|acc_norm  |↑  | 0.2553|±  |0.0067|
# |medtext |      1|none  |     0|bert_score|↑  | 0.7599|±  |0.0019|
# |        |       |none  |     0|bleu      |↑  | 0.0037|±  |0.0003|
# |        |       |none  |     0|bleurt    |↑  |-0.6702|±  |0.0050|
# |        |       |none  |     0|rouge1    |↑  | 0.0844|±  |0.0027|
# |        |       |none  |     0|rouge2    |↑  | 0.0147|±  |0.0006|
# |        |       |none  |     0|rougeL    |↑  | 0.0594|±  |0.0018|
# |pubmedqa|      1|none  |     0|acc       |↑  | 0.5740|±  |0.0221|

# %%
# !lm-eval \
  --model hf \
  --model_args pretrained=tiiuae/falcon-rw-1b \
  --tasks medmcqa,pubmedqa,medtext \
  --device cuda \
  --batch_size 32 \
  --trust_remote_code \
  --output_path eval_outputs/base_results.json
# Out:
# 2025-05-10 03:34:59.642096: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 03:34:59.660529: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746848099.683432   32851 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746848099.690454   32851 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-10 03:34:59.712907: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-10:03:35:06 INFO     [__main__:428] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-10:03:35:06 INFO     [__main__:440] Selected Tasks: ['medmcqa', 'medtext', 'pubmedqa']
# 2025-05-10:03:35:06 INFO     [evaluator:185] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-10:03:35:06 INFO     [evaluator:223] Initializing hf model, with arguments: {'pretrained': 'tiiuae/falcon-rw-1b', 'trust_remote_code': True}
# 2025-05-10:03:35:06 INFO     [models.huggingface:137] Using device 'cuda'
# 2025-05-10:03:35:06 INFO     [models.huggingface:382] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda'}
# INFO:tensorflow:Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# 2025-05-10:03:35:32 INFO     [tensorflow:160] Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# INFO:tensorflow:Config file found, reading.
# 2025-05-10:03:35:32 INFO     [tensorflow:91] Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# 2025-05-10:03:35:32 INFO     [tensorflow:95] Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# 2025-05-10:03:35:32 INFO     [tensorflow:97] Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# 2025-05-10:03:35:32 INFO     [tensorflow:101] ... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# 2025-05-10:03:35:32 INFO     [tensorflow:101] ... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# 2025-05-10:03:35:32 INFO     [tensorflow:101] ... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# 2025-05-10:03:35:32 INFO     [tensorflow:101] ... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# 2025-05-10:03:35:32 INFO     [tensorflow:101] ... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# 2025-05-10:03:35:32 INFO     [tensorflow:167] Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# 2025-05-10:03:35:32 INFO     [tensorflow:40] Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# 2025-05-10:03:35:32 INFO     [tensorflow:45] WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# 2025-05-10:03:35:32 INFO     [tensorflow:56] Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# 2025-05-10:03:35:32 INFO     [tensorflow:61] Loading model.
# 2025-05-10 03:35:32.684782: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1746848132.684937   32851 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 35844 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# 2025-05-10:03:35:34 INFO     [absl:1083] Fingerprint not found. Saved model loading will continue.
# 2025-05-10:03:35:34 INFO     [absl:1102] path_and_singleprint metric could not be logged. Saved model loading will continue.
# INFO:tensorflow:BLEURT initialized.
# 2025-05-10:03:35:34 INFO     [tensorflow:173] BLEURT initialized.
# INFO:tensorflow:Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# 2025-05-10:03:35:37 INFO     [tensorflow:160] Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# INFO:tensorflow:Config file found, reading.
# 2025-05-10:03:35:37 INFO     [tensorflow:91] Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# 2025-05-10:03:35:37 INFO     [tensorflow:95] Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# 2025-05-10:03:35:37 INFO     [tensorflow:97] Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# 2025-05-10:03:35:37 INFO     [tensorflow:101] ... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# 2025-05-10:03:35:37 INFO     [tensorflow:101] ... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# 2025-05-10:03:35:37 INFO     [tensorflow:101] ... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# 2025-05-10:03:35:37 INFO     [tensorflow:101] ... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# 2025-05-10:03:35:37 INFO     [tensorflow:101] ... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# 2025-05-10:03:35:37 INFO     [tensorflow:167] Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# 2025-05-10:03:35:37 INFO     [tensorflow:40] Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# 2025-05-10:03:35:37 INFO     [tensorflow:45] WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# 2025-05-10:03:35:37 INFO     [tensorflow:56] Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# 2025-05-10:03:35:37 INFO     [tensorflow:61] Loading model.
# 2025-05-10:03:35:39 INFO     [absl:1083] Fingerprint not found. Saved model loading will continue.
# 2025-05-10:03:35:39 INFO     [absl:1102] path_and_singleprint metric could not be logged. Saved model loading will continue.
# INFO:tensorflow:BLEURT initialized.
# 2025-05-10:03:35:39 INFO     [tensorflow:173] BLEURT initialized.
# INFO:tensorflow:Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# 2025-05-10:03:35:41 INFO     [tensorflow:160] Reading checkpoint /root/.cache/huggingface/metrics/bleurt/bleurt-base-512/downloads/extracted/08d25c43cb318d349f4ba702cd8f013a43b67f8561968947ba9da1eb85e68ead/bleurt-base-512.
# INFO:tensorflow:Config file found, reading.
# 2025-05-10:03:35:41 INFO     [tensorflow:91] Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# 2025-05-10:03:35:41 INFO     [tensorflow:95] Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# 2025-05-10:03:35:41 INFO     [tensorflow:97] Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# 2025-05-10:03:35:41 INFO     [tensorflow:101] ... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# 2025-05-10:03:35:41 INFO     [tensorflow:101] ... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# 2025-05-10:03:35:41 INFO     [tensorflow:101] ... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# 2025-05-10:03:35:41 INFO     [tensorflow:101] ... do_lower_case:True
# INFO:tensorflow:... max_seq_length:512
# 2025-05-10:03:35:41 INFO     [tensorflow:101] ... max_seq_length:512
# INFO:tensorflow:Creating BLEURT scorer.
# 2025-05-10:03:35:41 INFO     [tensorflow:167] Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# 2025-05-10:03:35:41 INFO     [tensorflow:40] Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# 2025-05-10:03:35:42 INFO     [tensorflow:45] WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# 2025-05-10:03:35:42 INFO     [tensorflow:56] Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# 2025-05-10:03:35:42 INFO     [tensorflow:61] Loading model.
# 2025-05-10:03:35:43 INFO     [absl:1083] Fingerprint not found. Saved model loading will continue.
# 2025-05-10:03:35:43 INFO     [absl:1102] path_and_singleprint metric could not be logged. Saved model loading will continue.
# INFO:tensorflow:BLEURT initialized.
# 2025-05-10:03:35:43 INFO     [tensorflow:173] BLEURT initialized.
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-10:03:35:45 INFO     [evaluator:286] medtext: Using gen_kwargs: {'until': ['\n\n']}
# 2025-05-10:03:35:45 INFO     [api.task:434] Building contexts for pubmedqa on rank 0...
# 100% 500/500 [00:00<00:00, 79407.50it/s]
# 2025-05-10:03:35:45 INFO     [api.task:434] Building contexts for medtext on rank 0...
# 100% 1412/1412 [00:00<00:00, 3165.57it/s]
# 2025-05-10:03:35:45 INFO     [api.task:434] Building contexts for medmcqa on rank 0...
# 100% 4183/4183 [00:00<00:00, 83226.32it/s]
# 2025-05-10:03:35:46 INFO     [evaluator:559] Running loglikelihood requests
# Running loglikelihood requests: 100% 18232/18232 [00:13<00:00, 1335.43it/s]
# 2025-05-10:03:36:09 INFO     [evaluator:559] Running generate_until requests
# Running generate_until requests: 100% 1412/1412 [04:49<00:00,  4.88it/s]
# 2025-05-10:03:40:58 INFO     [absl:83] Using default tokenizer.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2025-05-10:03:41:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:41:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:09 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:10 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:11 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:12 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:13 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:14 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:42:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:05 INFO     [absl:83] Using default tokenizer.
# ...
# 2025-05-10:03:43:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:15 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:16 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:17 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:18 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:19 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:20 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:21 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:22 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:23 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:24 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:25 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:26 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:27 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:28 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:29 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:30 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:31 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:32 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:33 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:34 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:35 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:36 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:37 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:38 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:39 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:40 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:41 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:42 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:43 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:44 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:45 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:46 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:47 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:48 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:49 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:50 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:51 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:52 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:53 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:54 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:55 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:56 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:57 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:58 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:43:59 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:00 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:01 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:02 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:03 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:04 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:05 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:06 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:07 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:08 INFO     [absl:83] Using default tokenizer.
# 2025-05-10:03:44:08 INFO     [absl:83] Using default tokenizer.
